# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
planets = sns.load_dataset('planets')

# %%
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
sns.relplot(x='year', y='distance', data=planets)

# %%
sns.relplot(x='year', y='distance', data=planets)

# %%
combined_years = planets.groupby('year', as_index=False).sum()
combined_years
# Out:
#     year  number  orbital_period       mass  distance
# 0   1989       1       83.888000   11.68000     40.57
# 1   1992       6       91.803900    0.00000      0.00
# 2   1994       3       98.211400    0.00000      0.00
# 3   1995       1        4.230785    0.47200     15.36
# 4   1996      15     2015.769933    7.91760     95.20
# 5   1997       1       39.845000    1.04000     17.43
# 6   1998      11      571.553306   13.43560    131.51
# 7   1999      24     8284.213789   45.31300    464.21
# 8   2000      27     8655.125170   50.86220    492.04
# 9   2001      15     8823.652700   37.74000    438.38
# 10  2002      46    31098.693942  122.05600   1376.28
# 11  2003      35    54550.912880   80.54100   1034.05
# 12  2004      41    11836.848236   21.81400   4249.89
# 13  2005      64    28195.315999   68.13250   1719.92
# 14  2006      43   749338.718705   35.99600  18486.41
# 15  2007      65    18915.474897  118.46700   7319.52
# ...

# %% [markdown]
# #### relation between the far distance of the discovered  planed from the earth  and the year of discovering it

# %%
sns.relplot(x='year', y='distance', data=combined_years)

# %% [markdown]
# ## Train a model using Seaborn

# %%
sns.lmplot(x='year', y='distance', data=combined_years)

# %%
sns.barplot(x='year', y='distance', data=combined_years)
# Out:
# <AxesSubplot:xlabel='year', ylabel='distance'>

# %% [markdown]
# #### relation between the number of the discovered planet and the year of discovering it

# %%
sns.relplot(x='year', y='number', data=combined_years)

# %% [markdown]
# # conclusion
#   most of the planet that we know, was discovered  between the period from 1990 until 2010
# and these planets far from the earth  less than 10000  million km
#  the planets that are far from the earth more than 10000 million km, did have not discovered until 2010 to 2015 and that because it needs modern technology that did not exist in the past period
